# %%
import importlib
import lshape.generate_all_certificate

from lshape.generate_all_certificate import *
from lshape.visualize_lshape import *

importlib.reload(lshape.generate_all_certificate)
importlib.reload(lshape.visualize_lshape)
# Out:
# <module 'lshape.visualize_lshape' from '/home/DAVIDSON/mili/Senior-Thesis/lshape/visualize_lshape.py'>

# %%
solutions42 = solve_L_shape(4, 2)
# Out:
# Solving L-shape: 46solution [01:37,  2.13s/solution]
# No more solutions found.
# All 46 non-isomorphic solutions found.

# %%
visualize_color_grids(solutions42)

# %%
i = 1
visualize_color_grids([solutions42[i]])
isomorphic_group = generate_isomorphic_solutions(solutions42[i], 4, 2)
visualize_color_grids(isomorphic_group)
# Out:
# All 14 isomorphic solutions found.

# %%
solutions43 = solve_L_shape(4, 3)
print(len(solutions43))
